# %% [markdown]
# # EAP bulk DOI migration to new website
#
# **Context:** Endangered Archives Project assigns DOIs to digitisation projects, but a large number of these were assigned using their old website and the URLs need updating. First we fetch a list of all DOIs in the `bl.eap` account:

# %%
import httpx
import pandas as pdt
from dotenv import load_dotenv
from os import getenv

load_dotenv()
cl = httpx.Client(
    timeout=httpx.Timeout(5.0, read=60.0),
    auth=(getenv('DATACITE_ID'), getenv('DATACITE_PW')),
)

params = {
    "client-id": "bl.eap",
    "page[size]": 1000, # we know in advance there are less than 1000, so this will be exhaustive
}
result = cl.get("https://api.datacite.org/dois", params=params)
result.raise_for_status() # raise an error if any problems
data = result.json()["data"]

print(len(data), "total DOIs")

data = pd.json_normalize(data)
print(data.columns)
# Out:
# 377 total DOIs
# Index(['id', 'type', 'attributes.doi', 'attributes.identifiers',
#        'attributes.creators', 'attributes.titles', 'attributes.publisher',
#        'attributes.publicationYear', 'attributes.subjects',
#        'attributes.contributors', 'attributes.dates', 'attributes.language',
#        'attributes.types.ris', 'attributes.types.bibtex',
#        'attributes.types.citeproc', 'attributes.types.schemaOrg',
#        'attributes.types.resourceType', 'attributes.types.resourceTypeGeneral',
#        'attributes.relatedIdentifiers', 'attributes.sizes',
#        'attributes.formats', 'attributes.version', 'attributes.rightsList',
#        'attributes.descriptions', 'attributes.geoLocations',
#        'attributes.fundingReferences', 'attributes.url',
#        'attributes.contentUrl', 'attributes.metadataVersion',
#        'attributes.schemaVersion', 'attributes.source', 'attributes.isActive',
#        'attributes.state', 'attributes.reason', 'attributes.viewCount',
#        'attributes.downloadCount', 'attributes.referenceCount',
#        'attributes.citationCount', 'attributes.partCount',
#        'attributes.partOfCount', 'attributes.versionCount',
#        'attributes.versionOfCount', 'attributes.created',
#        'attributes.registered', 'attributes.published', 'attributes.updated',
#        'relationships.client.data.id', 'relationships.client.data.type'],
#       dtype='object')

# %% [markdown]
# The DOIs that need updating can be identified by their URL. A few start "https://eap.bl.uk/search/site/":

# %%
dois_search_site = data['attributes.url'].str.match(r"https?://eap.bl.uk/search/site/")
dois_search_site.sum()
# Out:
# 0

# %% [markdown]
# But most start "https://eap.bl.uk/database/overview_project.a4d":

# %%
dois_database = data['attributes.url'].str.match(r"https?://eap.bl.uk/database/overview_project.a4d")
dois_database.sum()
# Out:
# 0

# %% [markdown]
# We can combine these sets to give us the final list of DOIs to update, and at the same time we'll throw away all the columns except the two we need, and rename those to make them shorter:

# %%
updates = data[dois_search_site | dois_database][['attributes.doi', 'attributes.url']] \
    .rename({'attributes.doi': 'id', 'attributes.url': 'url'}, axis=1)
updates
# Out:
#                    id                                                url
# 41    10.15130/eap908  http://eap.bl.uk/database/overview_project.a4d...
# 42    10.15130/eap900  http://eap.bl.uk/database/overview_project.a4d...
# 43    10.15130/eap890  http://eap.bl.uk/database/overview_project.a4d...
# 44    10.15130/eap886  http://eap.bl.uk/database/overview_project.a4d...
# 45    10.15130/eap842  http://eap.bl.uk/database/overview_project.a4d...
# ..                ...                                                ...
# 333   10.15130/eap542  http://eap.bl.uk/database/overview_project.a4d...
# 350  10.15130/eap1262              https://eap.bl.uk/search/site/EAP1262
# 352  10.15130/eap1221              https://eap.bl.uk/search/site/EAP1221
# 354  10.15130/eap1234              https://eap.bl.uk/search/site/EAP1234
# 356  10.15130/eap1238              https://eap.bl.uk/search/site/EAP1238
#
# [297 rows x 2 columns]

# %% [markdown]
# ## What are the changes?
#
# All the new URLs follow a simple pattern: `https://eap.bl.uk/project/<uppercase project ID>`
#
# Since each DOI uses the *lowercase* Project ID as its suffix, we can extract these and then use them to form the new URL. We'll keep both so that EAP can check before we make the changes live.

# %%
updates['project'] = updates.id.map(lambda s: s.split('/')[1].upper())
updates['new_url'] = updates.project.map(lambda project_id: f'https://eap.bl.uk/project/{project_id}')
updates
# Out:
#                    id                                                url  \
# 41    10.15130/eap908  http://eap.bl.uk/database/overview_project.a4d...
# 42    10.15130/eap900  http://eap.bl.uk/database/overview_project.a4d...
# 43    10.15130/eap890  http://eap.bl.uk/database/overview_project.a4d...
# 44    10.15130/eap886  http://eap.bl.uk/database/overview_project.a4d...
# 45    10.15130/eap842  http://eap.bl.uk/database/overview_project.a4d...
# ..                ...                                                ...
# 333   10.15130/eap542  http://eap.bl.uk/database/overview_project.a4d...
# 350  10.15130/eap1262              https://eap.bl.uk/search/site/EAP1262
# 352  10.15130/eap1221              https://eap.bl.uk/search/site/EAP1221
# 354  10.15130/eap1234              https://eap.bl.uk/search/site/EAP1234
# 356  10.15130/eap1238              https://eap.bl.uk/search/site/EAP1238
#
#      project                            new_url
# 41    EAP908   https://eap.bl.uk/project/EAP908
# 42    EAP900   https://eap.bl.uk/project/EAP900
# 43    EAP890   https://eap.bl.uk/project/EAP890
# 44    EAP886   https://eap.bl.uk/project/EAP886
# 45    EAP842   https://eap.bl.uk/project/EAP842
# ..       ...                                ...
# 333   EAP542   https://eap.bl.uk/project/EAP542
# 350  EAP1262  https://eap.bl.uk/project/EAP1262
# 352  EAP1221  https://eap.bl.uk/project/EAP1221
# 354  EAP1234  https://eap.bl.uk/project/EAP1234
# 356  EAP1238  https://eap.bl.uk/project/EAP1238
#
# [297 rows x 4 columns]

# %% [markdown]
# Let's save that to a spreadsheet and send it to EAP to check whether the changes look right...

# %%
updates.to_excel('eap-changes.xlsx', encoding='utf8')

# %%
params_types =  {
    "resourceType": "Web page",
    "resourceTypeGeneral": "Other"
}

for doi in updates.itertuples():
    print(f"{doi.id}: {doi.url} => {doi.new_url}")
    params = {'data': {'attributes': {'url': doi.new_url, 'types': params_types}}}
    response = cl.put(f'https://api.datacite.org/dois/{doi.id}', json=params)
    response.raise_for_status()
    print('Status:', response.status_code)
# Out:
# 10.15130/eap908: http://eap.bl.uk/database/overview_project.a4d?projID=EAP908;r=41 => https://eap.bl.uk/project/EAP908
# Status: 200
# 10.15130/eap900: http://eap.bl.uk/database/overview_project.a4d?projID=EAP900;r=41 => https://eap.bl.uk/project/EAP900
# Status: 200
# 10.15130/eap890: http://eap.bl.uk/database/overview_project.a4d?projID=EAP890;r=41 => https://eap.bl.uk/project/EAP890
# Status: 200
# 10.15130/eap886: http://eap.bl.uk/database/overview_project.a4d?projID=EAP886;r=41 => https://eap.bl.uk/project/EAP886
# Status: 200
# 10.15130/eap842: http://eap.bl.uk/database/overview_project.a4d?projID=EAP842;r=41 => https://eap.bl.uk/project/EAP842
# Status: 200
# 10.15130/eap1094: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1094;r=41 => https://eap.bl.uk/project/EAP1094
# Status: 200
# 10.15130/eap1034: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1034;r=41 => https://eap.bl.uk/project/EAP1034
# Status: 200
# 10.15130/eap1063: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1063;r=41 => https://eap.bl.uk/project/EAP1063
# Status: 200
# 10.15130/eap1056: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1056;r=41 => https://eap.bl.uk/project/EAP1056
# Status: 200
# 10.15130/eap1054: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1054;r=41 => https://eap.bl.uk/project/EAP1054
# Status: 200
# 10.15130/eap1014: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1014;r=41 => https://eap.bl.uk/project/EAP1014
# Status: 200
# 10.15130/eap993: http://eap.bl.uk/database/overview_project.a4d?projID=EAP993;r=41 => https://eap.bl.uk/project/EAP993
# Status: 200
# 10.15130/eap1024: http://eap.bl.uk/database/overview_project.a4d?projID=EAP1024;r=41 => https://eap.bl.uk/project/EAP1024
# Status: 200
# 10.15130/eap942: http://eap.bl.uk/database/overview_project.a4d?projID=EAP942 => https://eap.bl.uk/project/EAP942
# Status: 200
# 10.15130/eap955: http://eap.bl.uk/database/overview_project.a4d?projID=EAP955 => https://eap.bl.uk/project/EAP955
# Status: 200
# 10.15130/eap951: http://eap.bl.uk/database/overview_project.a4d?projID=EAP951 => https://eap.bl.uk/project/EAP951
# Status: 200
# 10.15130/eap981: http://eap.bl.uk/database/overview_project.a4d?projID=EAP981 => https://eap.bl.uk/project/EAP981
# Status: 200
# 10.15130/eap945: http://eap.bl.uk/database/overview_project.a4d?projID=EAP945 => https://eap.bl.uk/project/EAP945
# Status: 200
# 10.15130/eap936: http://eap.bl.uk/database/overview_project.a4d?projID=EAP936 => https://eap.bl.uk/project/EAP936
# Status: 200
# 10.15130/eap938: http://eap.bl.uk/database/overview_project.a4d?projID=EAP938 => https://eap.bl.uk/project/EAP938
# Status: 200
# 10.15130/eap935: http://eap.bl.uk/database/overview_project.a4d?projID=EAP935 => https://eap.bl.uk/project/EAP935
# Status: 200
# 10.15130/eap927: http://eap.bl.uk/database/overview_project.a4d?projID=EAP927 => https://eap.bl.uk/project/EAP927
# Status: 200
# 10.15130/eap931: http://eap.bl.uk/database/overview_project.a4d?projID=EAP931 => https://eap.bl.uk/project/EAP931
# Status: 200
# 10.15130/eap921: http://eap.bl.uk/database/overview_project.a4d?projID=EAP921 => https://eap.bl.uk/project/EAP921
# Status: 200
# 10.15130/eap922: http://eap.bl.uk/database/overview_project.a4d?projID=EAP922 => https://eap.bl.uk/project/EAP922
# Status: 200
# 10.15130/eap923: http://eap.bl.uk/database/overview_project.a4d?projID=EAP923 => https://eap.bl.uk/project/EAP923
# Status: 200
# 10.15130/eap913: http://eap.bl.uk/database/overview_project.a4d?projID=EAP913 => https://eap.bl.uk/project/EAP913
# Status: 200
# 10.15130/eap914: http://eap.bl.uk/database/overview_project.a4d?projID=EAP914 => https://eap.bl.uk/project/EAP914
# Status: 200
# 10.15130/eap915: http://eap.bl.uk/database/overview_project.a4d?projID=EAP915 => https://eap.bl.uk/project/EAP915
# Status: 200
# 10.15130/eap920: http://eap.bl.uk/database/overview_project.a4d?projID=EAP920 => https://eap.bl.uk/project/EAP920
# Status: 200
# 10.15130/eap918: http://eap.bl.uk/database/overview_project.a4d?projID=EAP918 => https://eap.bl.uk/project/EAP918
# Status: 200
# 10.15130/eap906: http://eap.bl.uk/database/overview_project.a4d?projID=EAP906 => https://eap.bl.uk/project/EAP906
# Status: 200
# 10.15130/eap910: http://eap.bl.uk/database/overview_project.a4d?projID=EAP910 => https://eap.bl.uk/project/EAP910
# Status: 200
# 10.15130/eap894: http://eap.bl.uk/database/overview_project.a4d?projID=EAP894 => https://eap.bl.uk/project/EAP894
# Status: 200
# 10.15130/eap901: http://eap.bl.uk/database/overview_project.a4d?projID=EAP901 => https://eap.bl.uk/project/EAP901
# Status: 200
# 10.15130/eap896: http://eap.bl.uk/database/overview_project.a4d?projID=EAP896 => https://eap.bl.uk/project/EAP896
# Status: 200
# 10.15130/eap899: http://eap.bl.uk/database/overview_project.a4d?projID=EAP899 => https://eap.bl.uk/project/EAP899
# Status: 200
# 10.15130/eap880: http://eap.bl.uk/database/overview_project.a4d?projID=EAP880 => https://eap.bl.uk/project/EAP880
# Status: 200
# 10.15130/eap888: http://eap.bl.uk/database/overview_project.a4d?projID=EAP888 => https://eap.bl.uk/project/EAP888
# Status: 200
# 10.15130/eap855: http://eap.bl.uk/database/overview_project.a4d?projID=EAP855 => https://eap.bl.uk/project/EAP855
# Status: 200
# 10.15130/eap863: http://eap.bl.uk/database/overview_project.a4d?projID=EAP863 => https://eap.bl.uk/project/EAP863
# Status: 200
# 10.15130/eap844: http://eap.bl.uk/database/overview_project.a4d?projID=EAP844 => https://eap.bl.uk/project/EAP844
# Status: 200
# 10.15130/eap838: http://eap.bl.uk/database/overview_project.a4d?projID=EAP838 => https://eap.bl.uk/project/EAP838
# Status: 200
# 10.15130/eap835: http://eap.bl.uk/database/overview_project.a4d?projID=EAP835 => https://eap.bl.uk/project/EAP835
# Status: 200
# 10.15130/eap833: http://eap.bl.uk/database/overview_project.a4d?projID=EAP833 => https://eap.bl.uk/project/EAP833
# Status: 200
# 10.15130/eap823: http://eap.bl.uk/database/overview_project.a4d?projID=EAP823 => https://eap.bl.uk/project/EAP823
# Status: 200
# 10.15130/eap796: http://eap.bl.uk/database/overview_project.a4d?projID=EAP796 => https://eap.bl.uk/project/EAP796
# Status: 200
# 10.15130/eap816: http://eap.bl.uk/database/overview_project.a4d?projID=EAP816 => https://eap.bl.uk/project/EAP816
# Status: 200
# 10.15130/eap870: http://eap.bl.uk/database/overview_project.a4d?projID=EAP870 => https://eap.bl.uk/project/EAP870
# Status: 200
# 10.15130/eap617: http://eap.bl.uk/database/overview_project.a4d?projID=EAP617 => https://eap.bl.uk/project/EAP617
# Status: 200
# 10.15130/eap783: http://eap.bl.uk/database/overview_project.a4d?projID=EAP783 => https://eap.bl.uk/project/EAP783
# Status: 200
# 10.15130/eap847: http://eap.bl.uk/database/overview_project.a4d?projID=EAP847 => https://eap.bl.uk/project/EAP847
# Status: 200
# 10.15130/eap845: http://eap.bl.uk/database/overview_project.a4d?projID=EAP845 => https://eap.bl.uk/project/EAP845
# Status: 200
# 10.15130/eap848: http://eap.bl.uk/database/overview_project.a4d?projID=EAP848 => https://eap.bl.uk/project/EAP848
# Status: 200
# 10.15130/eap810: http://eap.bl.uk/database/overview_project.a4d?projID=EAP810 => https://eap.bl.uk/project/EAP810
# Status: 200
# 10.15130/eap843: http://eap.bl.uk/database/overview_project.a4d?projID=EAP843 => https://eap.bl.uk/project/EAP843
# Status: 200
# 10.15130/eap834: http://eap.bl.uk/database/overview_project.a4d?projID=EAP834 => https://eap.bl.uk/project/EAP834
# Status: 200
# 10.15130/eap813: http://eap.bl.uk/database/overview_project.a4d?projID=EAP813 => https://eap.bl.uk/project/EAP813
# Status: 200
# 10.15130/eap820: http://eap.bl.uk/database/overview_project.a4d?projID=EAP820 => https://eap.bl.uk/project/EAP820
# Status: 200
# 10.15130/eap794: http://eap.bl.uk/database/overview_project.a4d?projID=EAP794 => https://eap.bl.uk/project/EAP794
# Status: 200
# 10.15130/eap898: http://eap.bl.uk/database/overview_project.a4d?projID=EAP898;r=41 => https://eap.bl.uk/project/EAP898
# Status: 200
# 10.15130/eap957: http://eap.bl.uk/database/overview_project.a4d?projID=EAP957 => https://eap.bl.uk/project/EAP957
# Status: 200
# 10.15130/eap856: http://eap.bl.uk/database/overview_project.a4d?projID=EAP856 => https://eap.bl.uk/project/EAP856
# Status: 200
# 10.15130/eap839: http://eap.bl.uk/database/overview_project.a4d?projID=EAP839 => https://eap.bl.uk/project/EAP839
# Status: 200
# 10.15130/eap793: http://eap.bl.uk/database/overview_project.a4d?projID=EAP793 => https://eap.bl.uk/project/EAP793
# Status: 200
# 10.15130/eap797: http://eap.bl.uk/database/overview_project.a4d?projID=EAP797 => https://eap.bl.uk/project/EAP797
# Status: 200
# 10.15130/eap821: http://eap.bl.uk/database/overview_project.a4d?projID=EAP821 => https://eap.bl.uk/project/EAP821
# Status: 200
# 10.15130/eap727: http://eap.bl.uk/database/overview_project.a4d?projID=EAP727 => https://eap.bl.uk/project/EAP727
# Status: 200
# 10.15130/eap790: http://eap.bl.uk/database/overview_project.a4d?projID=EAP790 => https://eap.bl.uk/project/EAP790
# Status: 200
# 10.15130/eap753: http://eap.bl.uk/database/overview_project.a4d?projID=EAP753 => https://eap.bl.uk/project/EAP753
# Status: 200
# 10.15130/eap737: http://eap.bl.uk/database/overview_project.a4d?projID=EAP737 => https://eap.bl.uk/project/EAP737
# Status: 200
# 10.15130/eap164: http://eap.bl.uk/database/overview_project.a4d?projID=EAP164 => https://eap.bl.uk/project/EAP164
# Status: 200
# 10.15130/eap180: http://eap.bl.uk/database/overview_project.a4d?projID=EAP180 => https://eap.bl.uk/project/EAP180
# Status: 200
# 10.15130/eap201: http://eap.bl.uk/database/overview_project.a4d?projID=EAP201 => https://eap.bl.uk/project/EAP201
# Status: 200
# 10.15130/eap190: http://eap.bl.uk/database/overview_project.a4d?projID=EAP190 => https://eap.bl.uk/project/EAP190
# Status: 200
# 10.15130/eap160: http://eap.bl.uk/database/overview_project.a4d?projID=EAP160 => https://eap.bl.uk/project/EAP160
# Status: 200
# 10.15130/eap140: http://eap.bl.uk/database/overview_project.a4d?projID=EAP140 => https://eap.bl.uk/project/EAP140
# Status: 200
# 10.15130/eap149: http://eap.bl.uk/database/overview_project.a4d?projID=EAP149 => https://eap.bl.uk/project/EAP149
# Status: 200
# 10.15130/eap183: http://eap.bl.uk/database/overview_project.a4d?projID=EAP183 => https://eap.bl.uk/project/EAP183
# Status: 200
# 10.15130/eap121: http://eap.bl.uk/database/overview_project.a4d?projID=EAP121 => https://eap.bl.uk/project/EAP121
# Status: 200
# 10.15130/eap132: http://eap.bl.uk/database/overview_project.a4d?projID=EAP132 => https://eap.bl.uk/project/EAP132
# Status: 200
# 10.15130/eap103: http://eap.bl.uk/database/overview_project.a4d?projID=EAP103 => https://eap.bl.uk/project/EAP103
# Status: 200
# 10.15130/eap104: http://eap.bl.uk/database/overview_project.a4d?projID=EAP104 => https://eap.bl.uk/project/EAP104
# Status: 200
# 10.15130/eap115: http://eap.bl.uk/database/overview_project.a4d?projID=EAP115 => https://eap.bl.uk/project/EAP115
# Status: 200
# 10.15130/eap040: http://eap.bl.uk/database/overview_project.a4d?projID=EAP040 => https://eap.bl.uk/project/EAP040
# Status: 200
# 10.15130/eap032: http://eap.bl.uk/database/overview_project.a4d?projID=EAP032 => https://eap.bl.uk/project/EAP032
# Status: 200
# 10.15130/eap027: http://eap.bl.uk/database/overview_project.a4d?projID=EAP027 => https://eap.bl.uk/project/EAP027
# Status: 200
# 10.15130/eap010: http://eap.bl.uk/database/overview_project.a4d?projID=EAP010 => https://eap.bl.uk/project/EAP010
# Status: 200
# 10.15130/eap177: http://eap.bl.uk/database/overview_project.a4d?projID=EAP177 => https://eap.bl.uk/project/EAP177
# Status: 200
# 10.15130/eap012: http://eap.bl.uk/database/overview_project.a4d?projID=EAP012 => https://eap.bl.uk/project/EAP012
# Status: 200
# 10.15130/eap025: http://eap.bl.uk/database/overview_project.a4d?projID=EAP025 => https://eap.bl.uk/project/EAP025
# Status: 200
# 10.15130/eap031: http://eap.bl.uk/database/overview_project.a4d?projID=EAP031 => https://eap.bl.uk/project/EAP031
# Status: 200
# 10.15130/eap008: http://eap.bl.uk/database/overview_project.a4d?projID=EAP008 => https://eap.bl.uk/project/EAP008
# Status: 200
# 10.15130/eap171: http://eap.bl.uk/database/overview_project.a4d?projID=EAP171 => https://eap.bl.uk/project/EAP171
# Status: 200
# 10.15130/eap124: http://eap.bl.uk/database/overview_project.a4d?projID=EAP124 => https://eap.bl.uk/project/EAP124
# Status: 200
# 10.15130/eap127: http://eap.bl.uk/database/overview_project.a4d?projID=EAP127 => https://eap.bl.uk/project/EAP127
# Status: 200
# 10.15130/eap144: http://eap.bl.uk/database/overview_project.a4d?projID=EAP144 => https://eap.bl.uk/project/EAP144
# Status: 200
# 10.15130/eap119: http://eap.bl.uk/database/overview_project.a4d?projID=EAP119 => https://eap.bl.uk/project/EAP119
# Status: 200
# 10.15130/eap061: http://eap.bl.uk/database/overview_project.a4d?projID=EAP061 => https://eap.bl.uk/project/EAP061
# Status: 200
# 10.15130/eap099: http://eap.bl.uk/database/overview_project.a4d?projID=EAP099 => https://eap.bl.uk/project/EAP099
# Status: 200
# 10.15130/eap039: http://eap.bl.uk/database/overview_project.a4d?projID=EAP039 => https://eap.bl.uk/project/EAP039
# Status: 200
# 10.15130/eap022: http://eap.bl.uk/database/overview_project.a4d?projID=EAP022 => https://eap.bl.uk/project/EAP022
# Status: 200
# 10.15130/eap191: http://eap.bl.uk/database/overview_project.a4d?projID=EAP191 => https://eap.bl.uk/project/EAP191
# Status: 200
# 10.15130/eap139: http://eap.bl.uk/database/overview_project.a4d?projID=EAP139 => https://eap.bl.uk/project/EAP139
# Status: 200
# 10.15130/eap500: http://eap.bl.uk/database/overview_project.a4d?projID=EAP500 => https://eap.bl.uk/project/EAP500
# Status: 200
# 10.15130/eap507: http://eap.bl.uk/database/overview_project.a4d?projID=EAP507 => https://eap.bl.uk/project/EAP507
# Status: 200
# 10.15130/eap117: http://eap.bl.uk/database/overview_project.a4d?projID=EAP117 => https://eap.bl.uk/project/EAP117
# Status: 200
# 10.15130/eap071: http://eap.bl.uk/database/overview_project.a4d?projID=EAP071 => https://eap.bl.uk/project/EAP071
# Status: 200
# 10.15130/eap054: http://eap.bl.uk/database/overview_project.a4d?projID=EAP054 => https://eap.bl.uk/project/EAP054
# Status: 200
# 10.15130/eap057: http://eap.bl.uk/database/overview_project.a4d?projID=EAP057 => https://eap.bl.uk/project/EAP057
# Status: 200
# 10.15130/eap462: http://eap.bl.uk/database/overview_project.a4d?projID=EAP462 => https://eap.bl.uk/project/EAP462
# Status: 200
# 10.15130/eap023: http://eap.bl.uk/database/overview_project.a4d?projID=EAP023 => https://eap.bl.uk/project/EAP023
# Status: 200
# 10.15130/eap503: http://eap.bl.uk/database/overview_project.a4d?projID=EAP503 => https://eap.bl.uk/project/EAP503
# Status: 200
# 10.15130/eap450: http://eap.bl.uk/database/overview_project.a4d?projID=EAP450 => https://eap.bl.uk/project/EAP450
# Status: 200
# 10.15130/eap454: http://eap.bl.uk/database/overview_project.a4d?projID=EAP454 => https://eap.bl.uk/project/EAP454
# Status: 200
# 10.15130/eap521: http://eap.bl.uk/database/overview_project.a4d?projID=EAP521 => https://eap.bl.uk/project/EAP521
# Status: 200
# 10.15130/eap038: http://eap.bl.uk/database/overview_project.a4d?projID=EAP038 => https://eap.bl.uk/project/EAP038
# Status: 200
# 10.15130/eap488: http://eap.bl.uk/database/overview_project.a4d?projID=EAP488 => https://eap.bl.uk/project/EAP488
# Status: 200
# 10.15130/eap016: http://eap.bl.uk/database/overview_project.a4d?projID=EAP016 => https://eap.bl.uk/project/EAP016
# Status: 200
# 10.15130/eap485: http://eap.bl.uk/database/overview_project.a4d?projID=EAP485 => https://eap.bl.uk/project/EAP485
# Status: 200
# 10.15130/eap336: http://eap.bl.uk/database/overview_project.a4d?projID=EAP336 => https://eap.bl.uk/project/EAP336
# Status: 200
# 10.15130/eap341: http://eap.bl.uk/database/overview_project.a4d?projID=EAP341 => https://eap.bl.uk/project/EAP341
# Status: 200
# 10.15130/eap264: http://eap.bl.uk/database/overview_project.a4d?projID=EAP264 => https://eap.bl.uk/project/EAP264
# Status: 200
# 10.15130/eap153: http://eap.bl.uk/database/overview_project.a4d?projID=EAP153 => https://eap.bl.uk/project/EAP153
# Status: 200
# 10.15130/eap187: http://eap.bl.uk/database/overview_project.a4d?projID=EAP187 => https://eap.bl.uk/project/EAP187
# Status: 200
# 10.15130/eap218: http://eap.bl.uk/database/overview_project.a4d?projID=EAP218 => https://eap.bl.uk/project/EAP218
# Status: 200
# 10.15130/eap375: http://eap.bl.uk/database/overview_project.a4d?projID=EAP375 => https://eap.bl.uk/project/EAP375
# Status: 200
# 10.15130/eap166: http://eap.bl.uk/database/overview_project.a4d?projID=EAP166 => https://eap.bl.uk/project/EAP166
# Status: 200
# 10.15130/eap229: http://eap.bl.uk/database/overview_project.a4d?projID=EAP229 => https://eap.bl.uk/project/EAP229
# Status: 200
# 10.15130/eap372: http://eap.bl.uk/database/overview_project.a4d?projID=EAP372 => https://eap.bl.uk/project/EAP372
# Status: 200
# 10.15130/eap401: http://eap.bl.uk/database/overview_project.a4d?projID=EAP401 => https://eap.bl.uk/project/EAP401
# Status: 200
# 10.15130/eap089: http://eap.bl.uk/database/overview_project.a4d?projID=EAP089 => https://eap.bl.uk/project/EAP089
# Status: 200
# 10.15130/eap326: http://eap.bl.uk/database/overview_project.a4d?projID=EAP326 => https://eap.bl.uk/project/EAP326
# Status: 200
# 10.15130/eap081: http://eap.bl.uk/database/overview_project.a4d?projID=EAP081 => https://eap.bl.uk/project/EAP081
# Status: 200
# 10.15130/eap087: http://eap.bl.uk/database/overview_project.a4d?projID=EAP087 => https://eap.bl.uk/project/EAP087
# Status: 200
# 10.15130/eap281: http://eap.bl.uk/database/overview_project.a4d?projID=EAP281 => https://eap.bl.uk/project/EAP281
# Status: 200
# 10.15130/eap284: http://eap.bl.uk/database/overview_project.a4d?projID=EAP284 => https://eap.bl.uk/project/EAP284
# Status: 200
# 10.15130/eap285: http://eap.bl.uk/database/overview_project.a4d?projID=EAP285 => https://eap.bl.uk/project/EAP285
# Status: 200
# 10.15130/eap255: http://eap.bl.uk/database/overview_project.a4d?projID=EAP255 => https://eap.bl.uk/project/EAP255
# Status: 200
# 10.15130/eap262: http://eap.bl.uk/database/overview_project.a4d?projID=EAP262 => https://eap.bl.uk/project/EAP262
# Status: 200
# 10.15130/eap265: http://eap.bl.uk/database/overview_project.a4d?projID=EAP265 => https://eap.bl.uk/project/EAP265
# Status: 200
# 10.15130/eap001: http://eap.bl.uk/database/overview_project.a4d?projID=EAP001 => https://eap.bl.uk/project/EAP001
# Status: 200
# 10.15130/eap005: http://eap.bl.uk/database/overview_project.a4d?projID=EAP005 => https://eap.bl.uk/project/EAP005
# Status: 200
# 10.15130/eap250: http://eap.bl.uk/database/overview_project.a4d?projID=EAP250 => https://eap.bl.uk/project/EAP250
# Status: 200
# 10.15130/eap209: http://eap.bl.uk/database/overview_project.a4d?projID=EAP209 => https://eap.bl.uk/project/EAP209
# Status: 200
# 10.15130/eap219: http://eap.bl.uk/database/overview_project.a4d?projID=EAP219 => https://eap.bl.uk/project/EAP219
# Status: 200
# 10.15130/eap506: http://eap.bl.uk/database/overview_project.a4d?projID=EAP506 => https://eap.bl.uk/project/EAP506
# Status: 200
# 10.15130/eap468: http://eap.bl.uk/database/overview_project.a4d?projID=EAP468 => https://eap.bl.uk/project/EAP468
# Status: 200
# 10.15130/eap759: http://eap.bl.uk/database/overview_project.a4d?projID=EAP759 => https://eap.bl.uk/project/EAP759
# Status: 200
# 10.15130/eap691: http://eap.bl.uk/database/overview_project.a4d?projID=EAP691 => https://eap.bl.uk/project/EAP691
# Status: 200
# 10.15130/eap690: http://eap.bl.uk/database/overview_project.a4d?projID=EAP690 => https://eap.bl.uk/project/EAP690
# Status: 200
# 10.15130/eap698: http://eap.bl.uk/database/overview_project.a4d?projID=EAP698 => https://eap.bl.uk/project/EAP698
# Status: 200
# 10.15130/eap640: http://eap.bl.uk/database/overview_project.a4d?projID=EAP640 => https://eap.bl.uk/project/EAP640
# Status: 200
# 10.15130/eap643: http://eap.bl.uk/database/overview_project.a4d?projID=EAP643 => https://eap.bl.uk/project/EAP643
# Status: 200
# 10.15130/eap408: http://eap.bl.uk/database/overview_project.a4d?projID=EAP408 => https://eap.bl.uk/project/EAP408
# Status: 200
# 10.15130/eap656: http://eap.bl.uk/database/overview_project.a4d?projID=EAP656 => https://eap.bl.uk/project/EAP656
# Status: 200
# 10.15130/eap340: http://eap.bl.uk/database/overview_project.a4d?projID=EAP340 => https://eap.bl.uk/project/EAP340
# Status: 200
# 10.15130/eap357: http://eap.bl.uk/database/overview_project.a4d?projID=EAP357 => https://eap.bl.uk/project/EAP357
# Status: 200
# 10.15130/eap769: http://eap.bl.uk/database/overview_project.a4d?projID=EAP769 => https://eap.bl.uk/project/EAP769
# Status: 200
# 10.15130/eap365: http://eap.bl.uk/database/overview_project.a4d?projID=EAP365 => https://eap.bl.uk/project/EAP365
# Status: 200
# 10.15130/eap274: http://eap.bl.uk/database/overview_project.a4d?projID=EAP274 => https://eap.bl.uk/project/EAP274
# Status: 200
# 10.15130/eap276: http://eap.bl.uk/database/overview_project.a4d?projID=EAP276 => https://eap.bl.uk/project/EAP276
# Status: 200
# 10.15130/eap184: http://eap.bl.uk/database/overview_project.a4d?projID=EAP184 => https://eap.bl.uk/project/EAP184
# Status: 200
# 10.15130/eap618: http://eap.bl.uk/database/overview_project.a4d?projID=EAP618 => https://eap.bl.uk/project/EAP618
# Status: 200
# 10.15130/eap693: http://eap.bl.uk/database/overview_project.a4d?projID=EAP693 => https://eap.bl.uk/project/EAP693
# Status: 200
# 10.15130/eap703: http://eap.bl.uk/database/overview_project.a4d?projID=EAP703 => https://eap.bl.uk/project/EAP703
# Status: 200
# 10.15130/eap704: http://eap.bl.uk/database/overview_project.a4d?projID=EAP704 => https://eap.bl.uk/project/EAP704
# Status: 200
# 10.15130/eap760: http://eap.bl.uk/database/overview_project.a4d?projID=EAP760 => https://eap.bl.uk/project/EAP760
# Status: 200
# 10.15130/eap619: http://eap.bl.uk/database/overview_project.a4d?projID=EAP619 => https://eap.bl.uk/project/EAP619
# Status: 200
# 10.15130/eap272: http://eap.bl.uk/database/overview_project.a4d?projID=EAP272 => https://eap.bl.uk/project/EAP272
# Status: 200
# 10.15130/eap596: http://eap.bl.uk/database/overview_project.a4d?projID=EAP596 => https://eap.bl.uk/project/EAP596
# Status: 200
# 10.15130/eap498: http://eap.bl.uk/database/overview_project.a4d?projID=EAP498 => https://eap.bl.uk/project/EAP498
# Status: 200
# 10.15130/eap699: http://eap.bl.uk/database/overview_project.a4d?projID=EAP699 => https://eap.bl.uk/project/EAP699
# Status: 200
# 10.15130/eap295: http://eap.bl.uk/database/overview_project.a4d?projID=EAP295 => https://eap.bl.uk/project/EAP295
# Status: 200
# 10.15130/eap566: http://eap.bl.uk/database/overview_project.a4d?projID=EAP566 => https://eap.bl.uk/project/EAP566
# Status: 200
# 10.15130/eap128: http://eap.bl.uk/database/overview_project.a4d?projID=EAP128 => https://eap.bl.uk/project/EAP128
# Status: 200
# 10.15130/eap474: http://eap.bl.uk/database/overview_project.a4d?projID=EAP474 => https://eap.bl.uk/project/EAP474
# Status: 200
# 10.15130/eap217: http://eap.bl.uk/database/overview_project.a4d?projID=EAP217 => https://eap.bl.uk/project/EAP217
# Status: 200
# 10.15130/eap205: http://eap.bl.uk/database/overview_project.a4d?projID=EAP205 => https://eap.bl.uk/project/EAP205
# Status: 200
# 10.15130/eap550: http://eap.bl.uk/database/overview_project.a4d?projID=EAP550 => https://eap.bl.uk/project/EAP550
# Status: 200
# 10.15130/eap657: http://eap.bl.uk/database/overview_project.a4d?projID=EAP657 => https://eap.bl.uk/project/EAP657
# Status: 200
# 10.15130/eap683: http://eap.bl.uk/database/overview_project.a4d?projID=EAP683 => https://eap.bl.uk/project/EAP683
# Status: 200
# 10.15130/eap110: http://eap.bl.uk/database/overview_project.a4d?projID=EAP110 => https://eap.bl.uk/project/EAP110
# Status: 200
# 10.15130/eap088: http://eap.bl.uk/database/overview_project.a4d?projID=EAP088 => https://eap.bl.uk/project/EAP088
# Status: 200
# 10.15130/eap086: http://eap.bl.uk/database/overview_project.a4d?projID=EAP086 => https://eap.bl.uk/project/EAP086
# Status: 200
# 10.15130/eap066: http://eap.bl.uk/database/overview_project.a4d?projID=EAP066 => https://eap.bl.uk/project/EAP066
# Status: 200
# 10.15130/eap060: http://eap.bl.uk/database/overview_project.a4d?projID=EAP060 => https://eap.bl.uk/project/EAP060
# Status: 200
# 10.15130/eap433: http://eap.bl.uk/database/overview_project.a4d?projID=EAP433 => https://eap.bl.uk/project/EAP433
# Status: 200
# 10.15130/eap460: http://eap.bl.uk/database/overview_project.a4d?projID=EAP460 => https://eap.bl.uk/project/EAP460
# Status: 200
# 10.15130/eap531: http://eap.bl.uk/database/overview_project.a4d?projID=EAP531 => https://eap.bl.uk/project/EAP531
# Status: 200
# 10.15130/eap430: http://eap.bl.uk/database/overview_project.a4d?projID=EAP430 => https://eap.bl.uk/project/EAP430
# Status: 200
# 10.15130/eap449: http://eap.bl.uk/database/overview_project.a4d?projID=EAP449 => https://eap.bl.uk/project/EAP449
# Status: 200
# 10.15130/eap532: http://eap.bl.uk/database/overview_project.a4d?projID=EAP532 => https://eap.bl.uk/project/EAP532
# Status: 200
# 10.15130/eap078: http://eap.bl.uk/database/overview_project.a4d?projID=EAP078 => https://eap.bl.uk/project/EAP078
# Status: 200
# 10.15130/eap443: http://eap.bl.uk/database/overview_project.a4d?projID=EAP443 => https://eap.bl.uk/project/EAP443
# Status: 200
# 10.15130/eap571: http://eap.bl.uk/database/overview_project.a4d?projID=EAP571 => https://eap.bl.uk/project/EAP571
# Status: 200
# 10.15130/eap570: http://eap.bl.uk/database/overview_project.a4d?projID=EAP570 => https://eap.bl.uk/project/EAP570
# Status: 200
# 10.15130/eap368: http://eap.bl.uk/database/overview_project.a4d?projID=EAP368 => https://eap.bl.uk/project/EAP368
# Status: 200
# 10.15130/eap143: http://eap.bl.uk/database/overview_project.a4d?projID=EAP143 => https://eap.bl.uk/project/EAP143
# Status: 200
# 10.15130/eap148: http://eap.bl.uk/database/overview_project.a4d?projID=EAP148 => https://eap.bl.uk/project/EAP148
# Status: 200
# 10.15130/eap165: http://eap.bl.uk/database/overview_project.a4d?projID=EAP165 => https://eap.bl.uk/project/EAP165
# Status: 200
# 10.15130/eap310: http://eap.bl.uk/database/overview_project.a4d?projID=EAP310 => https://eap.bl.uk/project/EAP310
# Status: 200
# 10.15130/eap334: http://eap.bl.uk/database/overview_project.a4d?projID=EAP334 => https://eap.bl.uk/project/EAP334
# Status: 200
# 10.15130/eap105: http://eap.bl.uk/database/overview_project.a4d?projID=EAP105 => https://eap.bl.uk/project/EAP105
# Status: 200
# 10.15130/eap279: http://eap.bl.uk/database/overview_project.a4d?projID=EAP279 => https://eap.bl.uk/project/EAP279
# Status: 200
# 10.15130/eap095: http://eap.bl.uk/database/overview_project.a4d?projID=EAP095 => https://eap.bl.uk/project/EAP095
# Status: 200
# 10.15130/eap067: http://eap.bl.uk/database/overview_project.a4d?projID=EAP067 => https://eap.bl.uk/project/EAP067
# Status: 200
# 10.15130/eap529: http://eap.bl.uk/database/overview_project.a4d?projID=EAP529 => https://eap.bl.uk/project/EAP529
# Status: 200
# 10.15130/eap280: http://eap.bl.uk/database/overview_project.a4d?projID=EAP280 => https://eap.bl.uk/project/EAP280
# Status: 200
# 10.15130/eap080: http://eap.bl.uk/database/overview_project.a4d?projID=EAP080 => https://eap.bl.uk/project/EAP080
# Status: 200
# 10.15130/eap051: http://eap.bl.uk/database/overview_project.a4d?projID=EAP051 => https://eap.bl.uk/project/EAP051
# Status: 200
# 10.15130/eap234: http://eap.bl.uk/database/overview_project.a4d?projID=EAP234 => https://eap.bl.uk/project/EAP234
# Status: 200
# 10.15130/eap231: http://eap.bl.uk/database/overview_project.a4d?projID=EAP231 => https://eap.bl.uk/project/EAP231
# Status: 200
# 10.15130/eap052: http://eap.bl.uk/database/overview_project.a4d?projID=EAP052 => https://eap.bl.uk/project/EAP052
# Status: 200
# 10.15130/eap006: http://eap.bl.uk/database/overview_project.a4d?projID=EAP006 => https://eap.bl.uk/project/EAP006
# Status: 200
# 10.15130/eap248: http://eap.bl.uk/database/overview_project.a4d?projID=EAP248 => https://eap.bl.uk/project/EAP248
# Status: 200
# 10.15130/eap211: http://eap.bl.uk/database/overview_project.a4d?projID=EAP211 => https://eap.bl.uk/project/EAP211
# Status: 200
# 10.15130/eap261: http://eap.bl.uk/database/overview_project.a4d?projID=EAP261 => https://eap.bl.uk/project/EAP261
# Status: 200
# 10.15130/eap208: http://eap.bl.uk/database/overview_project.a4d?projID=EAP208 => https://eap.bl.uk/project/EAP208
# Status: 200
# 10.15130/eap749: http://eap.bl.uk/database/overview_project.a4d?projID=EAP749 => https://eap.bl.uk/project/EAP749
# Status: 200
# 10.15130/eap722: http://eap.bl.uk/database/overview_project.a4d?projID=EAP722 => https://eap.bl.uk/project/EAP722
# Status: 200
# 10.15130/eap714: http://eap.bl.uk/database/overview_project.a4d?projID=EAP714 => https://eap.bl.uk/project/EAP714
# Status: 200
# 10.15130/eap700: http://eap.bl.uk/database/overview_project.a4d?projID=EAP700 => https://eap.bl.uk/project/EAP700
# Status: 200
# 10.15130/eap636: http://eap.bl.uk/database/overview_project.a4d?projID=EAP636 => https://eap.bl.uk/project/EAP636
# Status: 200
# 10.15130/eap593: http://eap.bl.uk/database/overview_project.a4d?projID=EAP593 => https://eap.bl.uk/project/EAP593
# Status: 200
# 10.15130/eap548: http://eap.bl.uk/database/overview_project.a4d?projID=EAP548 => https://eap.bl.uk/project/EAP548
# Status: 200
# 10.15130/eap524: http://eap.bl.uk/database/overview_project.a4d?projID=EAP524 => https://eap.bl.uk/project/EAP524
# Status: 200
# 10.15130/eap526: http://eap.bl.uk/database/overview_project.a4d?projID=EAP526 => https://eap.bl.uk/project/EAP526
# Status: 200
# 10.15130/eap458: http://eap.bl.uk/database/overview_project.a4d?projID=EAP458 => https://eap.bl.uk/project/EAP458
# Status: 200
# 10.15130/eap781: http://eap.bl.uk/database/overview_project.a4d?projID=EAP781 => https://eap.bl.uk/project/EAP781
# Status: 200
# 10.15130/eap736: http://eap.bl.uk/database/overview_project.a4d?projID=EAP736 => https://eap.bl.uk/project/EAP736
# Status: 200
# 10.15130/eap373: http://eap.bl.uk/database/overview_project.a4d?projID=EAP373 => https://eap.bl.uk/project/EAP373
# Status: 200
# 10.15130/eap427: http://eap.bl.uk/database/overview_project.a4d?projID=EAP427 => https://eap.bl.uk/project/EAP427
# Status: 200
# 10.15130/eap383: http://eap.bl.uk/database/overview_project.a4d?projID=EAP383 => https://eap.bl.uk/project/EAP383
# Status: 200
# 10.15130/eap764: http://eap.bl.uk/database/overview_project.a4d?projID=EAP764 => https://eap.bl.uk/project/EAP764
# Status: 200
# 10.15130/eap387: http://eap.bl.uk/database/overview_project.a4d?projID=EAP387 => https://eap.bl.uk/project/EAP387
# Status: 200
# 10.15130/eap359: http://eap.bl.uk/database/overview_project.a4d?projID=EAP359 => https://eap.bl.uk/project/EAP359
# Status: 200
# 10.15130/eap692: http://eap.bl.uk/database/overview_project.a4d?projID=EAP692 => https://eap.bl.uk/project/EAP692
# Status: 200
# 10.15130/eap726: http://eap.bl.uk/database/overview_project.a4d?projID=EAP726 => https://eap.bl.uk/project/EAP726
# Status: 200
# 10.15130/eap329: http://eap.bl.uk/database/overview_project.a4d?projID=EAP329 => https://eap.bl.uk/project/EAP329
# Status: 200
# 10.15130/eap673: http://eap.bl.uk/database/overview_project.a4d?projID=EAP673 => https://eap.bl.uk/project/EAP673
# Status: 200
# 10.15130/eap314: http://eap.bl.uk/database/overview_project.a4d?projID=EAP314 => https://eap.bl.uk/project/EAP314
# Status: 200
# 10.15130/eap676: http://eap.bl.uk/database/overview_project.a4d?projID=EAP676 => https://eap.bl.uk/project/EAP676
# Status: 200
# 10.15130/eap688: http://eap.bl.uk/database/overview_project.a4d?projID=EAP688 => https://eap.bl.uk/project/EAP688
# Status: 200
# 10.15130/eap298: http://eap.bl.uk/database/overview_project.a4d?projID=EAP298 => https://eap.bl.uk/project/EAP298
# Status: 200
# 10.15130/eap660: http://eap.bl.uk/database/overview_project.a4d?projID=EAP660 => https://eap.bl.uk/project/EAP660
# Status: 200
# 10.15130/eap505: http://eap.bl.uk/database/overview_project.a4d?projID=EAP505 => https://eap.bl.uk/project/EAP505
# Status: 200
# 10.15130/eap266: http://eap.bl.uk/database/overview_project.a4d?projID=EAP266 => https://eap.bl.uk/project/EAP266
# Status: 200
# 10.15130/eap466: http://eap.bl.uk/database/overview_project.a4d?projID=EAP466 => https://eap.bl.uk/project/EAP466
# Status: 200
# 10.15130/eap256: http://eap.bl.uk/database/overview_project.a4d?projID=EAP256 => https://eap.bl.uk/project/EAP256
# Status: 200
# 10.15130/eap254: http://eap.bl.uk/database/overview_project.a4d?projID=EAP254 => https://eap.bl.uk/project/EAP254
# Status: 200
# 10.15130/eap212: http://eap.bl.uk/database/overview_project.a4d?projID=EAP212 => https://eap.bl.uk/project/EAP212
# Status: 200
# 10.15130/eap432: http://eap.bl.uk/database/overview_project.a4d?projID=EAP432 => https://eap.bl.uk/project/EAP432
# Status: 200
# 10.15130/eap602: http://eap.bl.uk/database/overview_project.a4d?projID=EAP602 => https://eap.bl.uk/project/EAP602
# Status: 200
# 10.15130/eap607: http://eap.bl.uk/database/overview_project.a4d?projID=EAP607 => https://eap.bl.uk/project/EAP607
# Status: 200
# 10.15130/eap399: http://eap.bl.uk/database/overview_project.a4d?projID=EAP399 => https://eap.bl.uk/project/EAP399
# Status: 200
# 10.15130/eap345: http://eap.bl.uk/database/overview_project.a4d?projID=EAP345 => https://eap.bl.uk/project/EAP345
# Status: 200
# 10.15130/eap333: http://eap.bl.uk/database/overview_project.a4d?projID=EAP333 => https://eap.bl.uk/project/EAP333
# Status: 200
# 10.15130/eap592: http://eap.bl.uk/database/overview_project.a4d?projID=EAP592 => https://eap.bl.uk/project/EAP592
# Status: 200
# 10.15130/eap556: http://eap.bl.uk/database/overview_project.a4d?projID=EAP556 => https://eap.bl.uk/project/EAP556
# Status: 200
# 10.15130/eap352: http://eap.bl.uk/database/overview_project.a4d?projID=EAP352 => https://eap.bl.uk/project/EAP352
# Status: 200
# 10.15130/eap323: http://eap.bl.uk/database/overview_project.a4d?projID=EAP323 => https://eap.bl.uk/project/EAP323
# Status: 200
# 10.15130/eap327: http://eap.bl.uk/database/overview_project.a4d?projID=EAP327 => https://eap.bl.uk/project/EAP327
# Status: 200
# 10.15130/eap535: http://eap.bl.uk/database/overview_project.a4d?projID=EAP535 => https://eap.bl.uk/project/EAP535
# Status: 200
# 10.15130/eap207: http://eap.bl.uk/database/overview_project.a4d?projID=EAP207 => https://eap.bl.uk/project/EAP207
# Status: 200
# 10.15130/eap756: http://eap.bl.uk/database/overview_project.a4d?projID=EAP756 => https://eap.bl.uk/project/EAP756
# Status: 200
# 10.15130/eap755: http://eap.bl.uk/database/overview_project.a4d?projID=EAP755 => https://eap.bl.uk/project/EAP755
# Status: 200
# 10.15130/eap696: http://eap.bl.uk/database/overview_project.a4d?projID=EAP696 => https://eap.bl.uk/project/EAP696
# Status: 200
# 10.15130/eap729: http://eap.bl.uk/database/overview_project.a4d?projID=EAP729 => https://eap.bl.uk/project/EAP729
# Status: 200
# 10.15130/eap687: http://eap.bl.uk/database/overview_project.a4d?projID=EAP687 => https://eap.bl.uk/project/EAP687
# Status: 200
# 10.15130/eap684: http://eap.bl.uk/database/overview_project.a4d?projID=EAP684 => https://eap.bl.uk/project/EAP684
# Status: 200
# 10.15130/eap347: http://eap.bl.uk/database/overview_project.a4d?projID=EAP347 => https://eap.bl.uk/project/EAP347
# Status: 200
# 10.15130/eap650: http://eap.bl.uk/database/overview_project.a4d?projID=EAP650 => https://eap.bl.uk/project/EAP650
# Status: 200
# 10.15130/eap767: http://eap.bl.uk/database/overview_project.a4d?projID=EAP767 => https://eap.bl.uk/project/EAP767
# Status: 200
# 10.15130/eap286: http://eap.bl.uk/database/overview_project.a4d?projID=EAP286 => https://eap.bl.uk/project/EAP286
# Status: 200
# 10.15130/eap638: http://eap.bl.uk/database/overview_project.a4d?projID=EAP638 => https://eap.bl.uk/project/EAP638
# Status: 200
# 10.15130/eap766: http://eap.bl.uk/database/overview_project.a4d?projID=EAP766 => https://eap.bl.uk/project/EAP766
# Status: 200
# 10.15130/eap627: http://eap.bl.uk/database/overview_project.a4d?projID=EAP627 => https://eap.bl.uk/project/EAP627
# Status: 200
# 10.15130/eap608: http://eap.bl.uk/database/overview_project.a4d?projID=EAP608 => https://eap.bl.uk/project/EAP608
# Status: 200
# 10.15130/eap626: http://eap.bl.uk/database/overview_project.a4d?projID=EAP626 => https://eap.bl.uk/project/EAP626
# Status: 200
# 10.15130/eap689: http://eap.bl.uk/database/overview_project.a4d?projID=EAP689 => https://eap.bl.uk/project/EAP689
# Status: 200
# 10.15130/eap675: http://eap.bl.uk/database/overview_project.a4d?projID=EAP675 => https://eap.bl.uk/project/EAP675
# Status: 200
# 10.15130/eap644: http://eap.bl.uk/database/overview_project.a4d?projID=EAP644 => https://eap.bl.uk/project/EAP644
# Status: 200
# 10.15130/eap630: http://eap.bl.uk/database/overview_project.a4d?projID=EAP630 => https://eap.bl.uk/project/EAP630
# Status: 200
# 10.15130/eap536: http://eap.bl.uk/database/overview_project.a4d?projID=EAP536 => https://eap.bl.uk/project/EAP536
# Status: 200
# 10.15130/eap613: http://eap.bl.uk/database/overview_project.a4d?projID=EAP613 => https://eap.bl.uk/project/EAP613
# Status: 200
# 10.15130/eap584: http://eap.bl.uk/database/overview_project.a4d?projID=EAP584 => https://eap.bl.uk/project/EAP584
# Status: 200
# 10.15130/eap609: http://eap.bl.uk/database/overview_project.a4d?projID=EAP609 => https://eap.bl.uk/project/EAP609
# Status: 200
# 10.15130/eap563: http://eap.bl.uk/database/overview_project.a4d?projID=EAP563 => https://eap.bl.uk/project/EAP563
# Status: 200
# 10.15130/eap569: http://eap.bl.uk/database/overview_project.a4d?projID=EAP569 => https://eap.bl.uk/project/EAP569
# Status: 200
# 10.15130/eap540: http://eap.bl.uk/database/overview_project.a4d?projID=EAP540 => https://eap.bl.uk/project/EAP540
# Status: 200
# 10.15130/eap541: http://eap.bl.uk/database/overview_project.a4d?projID=EAP541 => https://eap.bl.uk/project/EAP541
# Status: 200
# 10.15130/eap542: http://eap.bl.uk/database/overview_project.a4d?projID=EAP542 => https://eap.bl.uk/project/EAP542
# Status: 200
# 10.15130/eap1262: https://eap.bl.uk/search/site/EAP1262 => https://eap.bl.uk/project/EAP1262
# Status: 200
# 10.15130/eap1221: https://eap.bl.uk/search/site/EAP1221 => https://eap.bl.uk/project/EAP1221
# Status: 200
# 10.15130/eap1234: https://eap.bl.uk/search/site/EAP1234 => https://eap.bl.uk/project/EAP1234
# Status: 200
# 10.15130/eap1238: https://eap.bl.uk/search/site/EAP1238 => https://eap.bl.uk/project/EAP1238
# Status: 200
